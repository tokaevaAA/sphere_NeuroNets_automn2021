# %% [markdown]
# ## Семинар 7: "Методы оптимизации"

# %% [markdown]
# ФИО: Токаева Александра

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import torch
from torch import nn
from torchvision import datasets, transforms
from torch.autograd import Variable
# %matplotlib inline

from tqdm import tqdm

# %% [markdown]
# На этом семинаре мы попробуем сравнить различные методы оптимизации: GD, Momentum, NAG, Adagrad, Adadelta, Adam.

# %% [markdown]
# ### Часть 1: Реализация методов

# %% [markdown]
# Полезная функция: plt.contour
# Для всех экспериментов подберите параметры так, чтобы метод сошелся к ближайшему локальному минимуму. Все методы следует запускать из одной и той же точки.

# %% [markdown]
# <i> 1.1 Реализуйте методы GD, Momentum, NAG, Adagrad, Adadelta, Adam.</i>

# %%
class MyOptimizer:
    def __init__(self, parameters):
        self.parameters = list(parameters)

    def zero_grad(self):
        for param in self.parameters: 
            if param.grad is not None:
                param.grad.zero_()      
  
    def step(self, F):
        loss = F()
        loss.backward()
        
class MySGD(MyOptimizer):
    def __init__(self,parameters,lr=0.01):
        super().__init__(parameters)
        self.lr=lr
        
    def step(self,F):
        loss = F()
        loss.backward()
        with torch.no_grad():
            for param in self.parameters:      
                param-=self.lr*param.grad  
                
class MyMomentum(MyOptimizer):
    def __init__(self,parameters,lr=0.01,gamma=0.9):
        super().__init__(parameters)
        self.lr=lr
        self.gamma=gamma
        self.vs=[torch.zeros_like(param) for param in self.parameters]
        
    def step(self,F):
        loss = F()
        loss.backward()
        with torch.no_grad():
            for param,v in zip(self.parameters,self.vs):  
                v.set_(self.gamma*v + self.lr*param.grad) #v_t = gamma*v_{t-1} +lr*grad
                param-=v 
                
                
class MyNesterov(MyOptimizer):
    def __init__(self,parameters,lr=0.01,gamma=0.9):
        super().__init__(parameters)
        self.lr=lr
        self.gamma=gamma
        self.vs=[torch.zeros_like(param) for param in self.parameters]
        
    def step(self,F):
        with torch.no_grad():
            for param,v in zip(self.parameters,self.vs):  
                param-=self.gamma*v
                
        loss = F()
        loss.backward()
        with torch.no_grad():
            for param,v in zip(self.parameters,self.vs):
                param+=self.gamma*v
                v.set_(self.gamma*v + self.lr*param.grad) #v_t = gamma*v_{t-1} +lr*grad
                param-=v 
  

        
class MyAdagrad(MyOptimizer):
    def __init__(self,parameters,lr=0.01,eps=1e-8):
        super().__init__(parameters)
        self.lr=lr
        self.eps=eps
        self.Gs=[torch.zeros_like(param) for param in self.parameters]
        
    def step(self,F):
        loss = F()
        loss.backward()
        with torch.no_grad():
            for param,G in zip(self.parameters,self.Gs):
                G+=param.grad**2
                param-=self.lr/(torch.sqrt(G+self.eps))*param.grad
                
class MyAdam(MyOptimizer):
    def __init__(self,parameters,lr=0.01,b1=0.9, b2=0.999, eps=1e-8):
        super().__init__(parameters)
        self.lr=lr
        self.b1=b1
        self.b2=b2
        self.eps=eps
        self.Ms=[torch.zeros_like(param) for param in self.parameters]
        self.Vs=[torch.zeros_like(param) for param in self.parameters]
        self.iterations=1
        
    def step(self,F):
        loss = F()
        loss.backward()
        with torch.no_grad():
            for param,m,v in zip(self.parameters,self.Ms,self.Vs):
                m.set_(self.b1*m+(1-self.b1)*param.grad)
                v.set_(self.b2*v+(1-self.b2)*param.grad**2)
                m_hat=m/(1-self.b1**self.iterations)
                v_hat=v/(1-self.b2**self.iterations)
                param-=self.lr/(torch.sqrt(v_hat+self.eps))*m_hat
                
        self.iterations+=1
        
class MyRMSProp(MyOptimizer):
    def __init__(self, parameters, lr=0.01, gamma=0.9):
        super().__init__(parameters)
        
        self.lr = lr
        self.gamma = gamma
        self.eps = 10e-9
        self.Gs= [torch.zeros_like(param) for param in self.parameters]
        
    
    def step(self, F):
        super().step(F)
        
        with torch.no_grad():
            for param,G in zip(self.parameters,self.Gs):
                G.set_(self.gamma * G + (1 - self.gamma) * param.grad**2)
                
                param -= self.lr / torch.sqrt(G + self.eps) * param.grad
                
# class MyAdadelta(MyOptimizer):
#     def __init__(self, parameters, lr=0.01, gamma=0.9):
#         super().__init__(parameters)
#         self.lr = lr
#         self.gamma = gamma
#         self.eps = 10e-9
#         self.Gs= [torch.zeros_like(param) for param in self.parameters]
#         self.dThs= [torch.zeros_like(param) for param in self.parameters]
        
    
#     def step(self, F):
#         super().step(F)
#         with torch.no_grad():
#             for param,G,dth in zip(self.parameters,self.Gs,self.dThs):
#                 G.set_(self.gamma * G + (1 - self.gamma) * param.grad**2)
#                 tek_delta= torch.sqrt(dth+self.eps)/ torch.sqrt(G + self.eps) * param.grad
#                 param -= tek_delta
#                 dth.set_(self.gamma * dth + (1 - self.gamma) * tek_delta**2)

class MyAdadelta(MyOptimizer):
    def __init__(self, parameters, lr=0.01, gamma=0.9):
        super().__init__(parameters)
        
        self.lr = lr
        self.gamma = gamma
        self.eps = 10e-9
        self.Gs= [torch.zeros_like(param) for param in self.parameters]
        self.dThs= [torch.zeros_like(param) for param in self.parameters]
        
    
    def step(self, F):
        super().step(F)
        
        with torch.no_grad():
            for param,G,dth in zip(self.parameters,self.Gs,self.dThs):
                G.set_(self.gamma * G + (1 - self.gamma) * param.grad**2)
                tek_delta= torch.sqrt(dth+self.eps)/ torch.sqrt(G + self.eps) * param.grad
                param -= tek_delta
                dth.set_(self.gamma * dth + (1 - self.gamma) * tek_delta**2)

# %% [markdown]
# <i> 1.2 Сравните эти методы на функции $J(x, y) = x^2+y^2$</i>

# %%
def J(x,y):
    return x**2+y**2


optimizers=[MySGD,MyMomentum,MyNesterov,MyAdagrad,MyAdam,MyRMSProp,MyAdadelta]
RESULTS=[]

for optim in optimizers:
    v=torch.from_numpy(np.array([3,4],dtype=float))
    v.requires_grad=True
    opt=optim([v],lr=0.01)
    path=[]
    for i in range(10000):
        opt.zero_grad()
        opt.step(lambda v=v: J(v[0],v[1]))
        path.append((v.detach().numpy().copy()[0],v.detach().numpy().copy()[1],J(v[0],v[1]).detach().numpy().copy()))
    path=np.array(path)
    final_value=J(v[0],v[1])
    print(opt.__class__.__name__,final_value.item())
    RESULTS.append((final_value,path))

    
colors=['red','orange','yellow','green','blue','purple','pink']

plt.figure(figsize=(8,5))
for cl,opt, (final_value,path) in zip(colors,optimizers,RESULTS):
    plt.scatter(path[:,0],path[:,1],label=opt.__name__, color=cl)
plt.legend()
plt.show()



from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8, 5))
ax = fig.add_subplot(111, projection='3d')
# for cl,opt, (final_value,path) in zip(colors,optimizers,RESULTS):
#     path=np.array(path)
#     ax.plot(path[:,0],path[:,1],path[0,2],label=opt.__name__, color=cl, linewidth=5)

for cl,opt,path in zip(colors,optimizers,RESULTS):
    points = np.array(path[1])
    ax.plot(points[:, 0], points[:, 1], points[:, 2], label=opt.__name__, color=cl, linewidth=5)
plt.legend()
plt.show()
# Out:
# MySGD 8.30718454687537e-175
# MyMomentum 0.0
# MyNesterov 0.0
# MyAdagrad 6.551827766733908
# MyAdam 0.0
# MyRMSProp 4.999500000000008e-05
# MyAdadelta 5.721485610151056e-62

# %% [markdown]
# <i>1.3 Сравните эти методы на функции $J(x, y) = x^2sin(x)+y^2sin(y)$</i>

# %%
def J(x,y):
    return x**2*torch.sin(x)+y**2*torch.sin(y)



optimizers=[MySGD,MyMomentum,MyNesterov,MyAdagrad,MyAdam,MyRMSProp,MyAdadelta]
RESULTS=[]

for opt in optimizers:
    v=torch.from_numpy(np.array([3,4],dtype=float))
    v.requires_grad=True
    opt=opt([v],lr=0.001)
    path=[]
    for i in range(10000):
        opt.zero_grad()
        opt.step(lambda v=v: J(v[0],v[1]))
        path.append((v.detach().numpy().copy()[0],v.detach().numpy().copy()[1],J(v[0],v[1]).detach().numpy().copy()))
    path=np.array(path)
    final_value=J(v[0],v[1])
    print(opt.__class__.__name__,final_value.item())
    RESULTS.append((final_value,path))

    
colors=['red','orange','yellow','green','blue','purple','pink']

plt.figure(figsize=(8,5))
for cl,opt, (final_value,path) in zip(colors,optimizers,RESULTS):
    plt.scatter(path[:,0],path[:,1],label=opt.__name__, color=cl)
plt.legend()
plt.show()



from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8, 5))
ax = fig.add_subplot(111, projection='3d')
for cl,opt,path in zip(colors,optimizers,RESULTS):
    points = np.array(path[1])
    ax.plot(points[:, 0], points[:, 1], points[:, 2], label=opt.__name__, color=cl, linewidth=5)
plt.legend()
plt.show()
# Out:
# MySGD -48.16592044613666
# MyMomentum -48.16592044613666
# MyNesterov -48.16592044613666
# MyAdagrad -16.017044919398025
# MyAdam -48.16592044613666
# MyRMSProp -48.16591303151175
# MyAdadelta -48.165335850646194

# %% [markdown]
# <i>1.3 Сравните эти методы на функции $J(x,y)=x^2sin(x^2)+y^2sin(y^2)$</i>

# %%
def J(x,y):
    return x**2*torch.sin(x**2)+y**2*torch.sin(y**2)


optimizers=[MySGD,MyMomentum,MyNesterov,MyAdagrad,MyAdam,MyRMSProp,MyAdadelta]
RESULTS=[]

for opt in optimizers:
    v=torch.from_numpy(np.array([3,4],dtype=float))
    v.requires_grad=True
    opt=opt([v],lr=0.0001)
    path=[]
    for i in range(10000):
        opt.zero_grad()
        opt.step(lambda v=v: J(v[0],v[1]))
        path.append((v.detach().numpy().copy()[0],v.detach().numpy().copy()[1],J(v[0],v[1]).detach().numpy().copy()))
    path=np.array(path)
    final_value=J(v[0],v[1])
    print(opt.__class__.__name__,final_value.item())
    RESULTS.append((final_value,path))

    
colors=['red','orange','yellow','green','blue','purple','pink']

plt.figure(figsize=(8,5))
for cl,opt, (final_value,path) in zip(colors,optimizers,RESULTS):
    plt.scatter(path[:,0],path[:,1],label=opt.__name__, color=cl)
plt.legend()
plt.show()



from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8, 5))
ax = fig.add_subplot(111, projection='3d')
for cl,opt,path in zip(colors,optimizers,RESULTS):
    points = np.array(path[1])
    ax.plot(points[:, 0], points[:, 1], points[:, 2], label=opt.__name__, color=cl, linewidth=5)
plt.legend()
plt.show()
# Out:
# MySGD -28.348316623788513
# MyMomentum -28.348316623788513
# MyNesterov -28.348316623788513
# MyAdagrad -4.305957199471715
# MyAdam -28.348316623788513
# MyRMSProp -28.348314491683716
# MyAdadelta -28.328449181002064

# %% [markdown]
# ###  Часть 2: Обучение нейронной сети

# %% [markdown]
# <i> 2.1 Сравните графики обучения для полносвязной нейросети на методах Adam, Adagrad, AdaDelta и SGD (на MNIST). Для обучения используйте оптимизаторы из первой части, а не из pytorch. </i>

# %%
#!wget www.di.ens.fr/~lelarge/MNIST.tar.gz
#!tar -zxvf MNIST.tar.gz

# %%
transform = transforms.Compose([
                                   transforms.ToTensor(),
                                   transforms.Normalize((0.1307,), (0.3081,))
                               ])

train_dataset = datasets.MNIST('.', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST('.', train=False, transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=True)

# Dataloader
to_numpy = lambda x: x.numpy()
transform = transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                    ])
train_dataset = datasets.MNIST('.', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST('.', train=False, transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=128, shuffle=True)

images_train, labels_train = next(iter(train_loader))

# %%
## Usage example:
for X, y in train_loader:
    X = X.view(X.shape[0], -1)
    X = X.numpy() ### Converts torch.Tensor to numpy array
    y = y.numpy()
    pass

# %%
plt.figure(figsize=(6, 7))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.imshow(X[i].reshape(28, 28), cmap=plt.cm.Greys_r)
    plt.title(y[i])
    plt.axis('off')

# %% [markdown]
# <i> 2.2 Сравните графики обучения для сверточной нейросети на методах Adam, Adagrad, AdaDelta и SGD. </i>

# %%
#Проверим, что вообще обучается:

# %%
activation_func=torch.nn.Tanh
layers=[torch.nn.Linear(28*28,100), activation_func(), torch.nn.Linear(100,100), activation_func(), torch.nn.Linear(100,10)]

my_network=torch.nn.Sequential(*layers)

loss_neuron = torch.nn.NLLLoss()
optimizer=torch.optim.Adam(my_network.parameters(), lr=0.01)

mas_of_train_losses=[]

lgsfm = nn.LogSoftmax(dim=1)

for epoch in tqdm(range(2)):
    mas=[]
    for X, y in train_loader:
        X = X.view(X.shape[0], -1)
        optimizer.zero_grad()
        #preds=my_network.forward(X)
        #tek_loss=loss_neuron.forward(preds,y)
        #mas.append(tek_loss.detach().numpy().copy())
        #tek_loss.backward()
        def myfunc(p=(X,y)):
            tek_otv=loss_neuron(lgsfm(my_network.forward(p[0])),p[1])
            mas.append(tek_otv.detach().numpy().copy())
            return tek_otv
        optimizer.step(myfunc)
        #optimizer.step(lambda p=(X,y): loss_neuron(lgsfm(my_network.forward(p[0])),p[1]))
    mas_of_train_losses.append(np.mean(mas))
    
mas_of_train_losses
# Out:
# 100%|██████████| 2/2 [00:21<00:00, 10.95s/it]
# [2.3569279, 2.3569195]

# %%
#Обучим:

# %%
def train(my_network, myoptim,epochs=10, learning_rate=0.01):
    loss_neuron = torch.nn.NLLLoss()
    optimizer = myoptim(my_network.parameters(), lr=learning_rate)
    train_loss_epochs = []
    test_loss_epochs = []
    train_accuracy_epochs = []
    test_accuracy_epochs = []
    try:
        for epoch in tqdm(range(epochs)):
            losses = []
            accuracies = []
            for X, y in train_loader:
                X = X.view(X.shape[0], -1)
                optimizer.zero_grad()
                def myfunc(p=(X,y)):
                    preds=my_network.forward(p[0])
                    tek_otv=loss_neuron(lgsfm(preds),p[1])
                    losses.append(tek_otv.detach().numpy().copy())
                    mask=(np.argmax(preds.detach().numpy().copy(), axis=1)==y.detach().numpy().copy()).astype(int)
                    accuracies.append(mask.mean())
                    return tek_otv
                optimizer.step(myfunc)
            train_loss_epochs.append(np.mean(losses))
            train_accuracy_epochs.append(np.mean(accuracies))
            
            
            losses = []
            #accuracies = []    
            for X, y in test_loader:
                X = X.view(X.shape[0], -1)
                preds=my_network.forward(X)
                tek_otv=loss_neuron(lgsfm(preds),y)
                losses.append(tek_otv.detach().numpy().copy())
                mask=(np.argmax(preds.detach().numpy().copy(), axis=1)==y.detach().numpy().copy()).astype(int)
                accuracies.append(mask.mean())
            
            test_loss_epochs.append(np.mean(losses))
            test_accuracy_epochs.append(np.mean(accuracies))
            #clear_output(True)
            print('\rEpoch {0}... NLLLoss(Train/Test): {1:.3f}/{2:.3f} Accuracy(Train/Test): {3:.3f}/{4:.3f}'.format(
                        epoch, train_loss_epochs[-1], test_loss_epochs[-1],train_accuracy_epochs[-1], test_accuracy_epochs[-1]))
            
            
            
            plt.figure(figsize=(12, 5))
            plt.subplot(1, 1, 1)
            plt.plot(train_loss_epochs, label='Train')
            plt.plot(test_loss_epochs, label='Test')
            plt.xlabel('Epochs', fontsize=16)
            plt.ylabel('Loss', fontsize=16)
            plt.legend(loc=0, fontsize=16)
            plt.grid()
            plt.show()
    except KeyboardInterrupt:
        pass

# %%
activation_func=torch.nn.Tanh
layers=[torch.nn.Linear(28*28,100), activation_func(), torch.nn.Linear(100,100), activation_func(), torch.nn.Linear(100,10)]

my_network1=torch.nn.Sequential(*layers)

# %time train(my_network1,MySGD,epochs=10, learning_rate=0.05)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 0... NLLLoss(Train/Test): 0.532/0.271 Accuracy(Train/Test): 0.870/0.878
#  10%|█         | 1/10 [00:12<01:54, 12.75s/it]
# Epoch 1... NLLLoss(Train/Test): 0.238/0.204 Accuracy(Train/Test): 0.933/0.934
#  20%|██        | 2/10 [00:27<01:52, 14.11s/it]
# Epoch 2... NLLLoss(Train/Test): 0.181/0.161 Accuracy(Train/Test): 0.949/0.949
#  30%|███       | 3/10 [00:47<01:55, 16.45s/it]
# Epoch 3... NLLLoss(Train/Test): 0.145/0.138 Accuracy(Train/Test): 0.959/0.959
#  40%|████      | 4/10 [01:03<01:37, 16.27s/it]
# Epoch 4... NLLLoss(Train/Test): 0.121/0.122 Accuracy(Train/Test): 0.966/0.966
#  50%|█████     | 5/10 [01:18<01:19, 15.83s/it]
# Epoch 5... NLLLoss(Train/Test): 0.102/0.113 Accuracy(Train/Test): 0.971/0.971
#  60%|██████    | 6/10 [01:34<01:03, 15.92s/it]
# Epoch 6... NLLLoss(Train/Test): 0.088/0.096 Accuracy(Train/Test): 0.976/0.975
#  70%|███████   | 7/10 [01:48<00:46, 15.35s/it]
# Epoch 7... NLLLoss(Train/Test): 0.077/0.092 Accuracy(Train/Test): 0.979/0.978
#  80%|████████  | 8/10 [02:05<00:31, 15.90s/it]
# Epoch 8... NLLLoss(Train/Test): 0.068/0.086 Accuracy(Train/Test): 0.982/0.981
#  90%|█████████ | 9/10 [02:18<00:15, 15.01s/it]
# Epoch 9... NLLLoss(Train/Test): 0.060/0.085 Accuracy(Train/Test): 0.984/0.982
# 100%|██████████| 10/10 [02:31<00:00, 15.14s/it]
# CPU times: user 2min 19s, sys: 3.11 s, total: 2min 22s
# Wall time: 2min 31s

# %%
my_network2=torch.nn.Sequential(*layers)
# %time train(my_network2,MyMomentum,epochs=10, learning_rate=0.05)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 0... NLLLoss(Train/Test): 0.105/0.097 Accuracy(Train/Test): 0.967/0.967
#  10%|█         | 1/10 [00:13<02:00, 13.40s/it]
# Epoch 1... NLLLoss(Train/Test): 0.070/0.101 Accuracy(Train/Test): 0.977/0.976
#  20%|██        | 2/10 [00:26<01:44, 13.04s/it]
# Epoch 2... NLLLoss(Train/Test): 0.048/0.094 Accuracy(Train/Test): 0.984/0.983
#  30%|███       | 3/10 [00:39<01:30, 13.00s/it]
# Epoch 3... NLLLoss(Train/Test): 0.038/0.083 Accuracy(Train/Test): 0.988/0.986
#  40%|████      | 4/10 [00:51<01:17, 12.88s/it]
# Epoch 4... NLLLoss(Train/Test): 0.032/0.080 Accuracy(Train/Test): 0.990/0.988
#  50%|█████     | 5/10 [01:06<01:06, 13.36s/it]
# Epoch 5... NLLLoss(Train/Test): 0.022/0.083 Accuracy(Train/Test): 0.993/0.990
#  60%|██████    | 6/10 [01:19<00:54, 13.53s/it]
# Epoch 6... NLLLoss(Train/Test): 0.021/0.096 Accuracy(Train/Test): 0.993/0.990
#  70%|███████   | 7/10 [01:32<00:39, 13.31s/it]
# Epoch 7... NLLLoss(Train/Test): 0.015/0.091 Accuracy(Train/Test): 0.995/0.993
#  80%|████████  | 8/10 [01:45<00:26, 13.10s/it]
# Epoch 8... NLLLoss(Train/Test): 0.013/0.099 Accuracy(Train/Test): 0.996/0.993
#  90%|█████████ | 9/10 [01:58<00:12, 12.95s/it]
# Epoch 9... NLLLoss(Train/Test): 0.009/0.097 Accuracy(Train/Test): 0.998/0.994
# 100%|██████████| 10/10 [02:10<00:00, 13.06s/it]
# CPU times: user 2min 7s, sys: 2.34 s, total: 2min 9s
# Wall time: 2min 10s

# %%
my_network3=torch.nn.Sequential(*layers)
# %time train(my_network3,MyNesterov,epochs=10, learning_rate=0.05)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 0... NLLLoss(Train/Test): 0.005/0.088 Accuracy(Train/Test): 0.999/0.996
#  10%|█         | 1/10 [00:12<01:56, 12.92s/it]
# Epoch 1... NLLLoss(Train/Test): 0.003/0.089 Accuracy(Train/Test): 1.000/0.996
#  20%|██        | 2/10 [00:26<01:44, 13.06s/it]
# Epoch 2... NLLLoss(Train/Test): 0.001/0.091 Accuracy(Train/Test): 1.000/0.997
#  30%|███       | 3/10 [00:38<01:30, 12.93s/it]
# Epoch 3... NLLLoss(Train/Test): 0.001/0.085 Accuracy(Train/Test): 1.000/0.997
#  40%|████      | 4/10 [00:51<01:17, 12.90s/it]
# Epoch 4... NLLLoss(Train/Test): 0.001/0.091 Accuracy(Train/Test): 1.000/0.997
#  50%|█████     | 5/10 [01:04<01:04, 12.86s/it]
# Epoch 5... NLLLoss(Train/Test): 0.001/0.087 Accuracy(Train/Test): 1.000/0.997
#  60%|██████    | 6/10 [01:17<00:51, 12.90s/it]
# Epoch 6... NLLLoss(Train/Test): 0.000/0.089 Accuracy(Train/Test): 1.000/0.997
#  70%|███████   | 7/10 [01:30<00:38, 12.88s/it]
# Epoch 7... NLLLoss(Train/Test): 0.000/0.087 Accuracy(Train/Test): 1.000/0.997
#  80%|████████  | 8/10 [01:42<00:25, 12.81s/it]
# Epoch 8... NLLLoss(Train/Test): 0.000/0.087 Accuracy(Train/Test): 1.000/0.997
#  90%|█████████ | 9/10 [01:55<00:12, 12.76s/it]
# Epoch 9... NLLLoss(Train/Test): 0.000/0.088 Accuracy(Train/Test): 1.000/0.997
# 100%|██████████| 10/10 [02:09<00:00, 12.98s/it]
# CPU times: user 2min 7s, sys: 2.48 s, total: 2min 9s
# Wall time: 2min 9s

# %%
my_network4=torch.nn.Sequential(*layers)
# %time train(my_network4,MyAdagrad,epochs=10, learning_rate=0.05)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 0... NLLLoss(Train/Test): 0.323/0.144 Accuracy(Train/Test): 0.921/0.926
#  10%|█         | 1/10 [00:16<02:32, 16.91s/it]
# Epoch 1... NLLLoss(Train/Test): 0.114/0.128 Accuracy(Train/Test): 0.965/0.964
#  20%|██        | 2/10 [00:36<02:27, 18.48s/it]
# Epoch 2... NLLLoss(Train/Test): 0.084/0.128 Accuracy(Train/Test): 0.974/0.972
#  30%|███       | 3/10 [00:49<01:53, 16.19s/it]
# Epoch 3... NLLLoss(Train/Test): 0.067/0.115 Accuracy(Train/Test): 0.979/0.977
#  40%|████      | 4/10 [01:03<01:30, 15.11s/it]
# Epoch 4... NLLLoss(Train/Test): 0.053/0.106 Accuracy(Train/Test): 0.984/0.982
#  50%|█████     | 5/10 [01:16<01:12, 14.48s/it]
# Epoch 5... NLLLoss(Train/Test): 0.041/0.103 Accuracy(Train/Test): 0.988/0.985
#  60%|██████    | 6/10 [01:30<00:56, 14.13s/it]
# Epoch 6... NLLLoss(Train/Test): 0.033/0.103 Accuracy(Train/Test): 0.991/0.988
#  70%|███████   | 7/10 [01:43<00:41, 13.82s/it]
# Epoch 7... NLLLoss(Train/Test): 0.028/0.103 Accuracy(Train/Test): 0.992/0.989
#  80%|████████  | 8/10 [01:56<00:27, 13.60s/it]
# Epoch 8... NLLLoss(Train/Test): 0.023/0.103 Accuracy(Train/Test): 0.994/0.991
#  90%|█████████ | 9/10 [02:09<00:13, 13.50s/it]
# Epoch 9... NLLLoss(Train/Test): 0.019/0.103 Accuracy(Train/Test): 0.995/0.992
# 100%|██████████| 10/10 [02:23<00:00, 14.31s/it]
# CPU times: user 2min 16s, sys: 3.08 s, total: 2min 19s
# Wall time: 2min 23s

# %%
my_network5=torch.nn.Sequential(*layers)
# %time train(my_network5,MyAdam,epochs=10, learning_rate=0.05)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 0... NLLLoss(Train/Test): 0.787/0.855 Accuracy(Train/Test): 0.761/0.759
#  10%|█         | 1/10 [00:13<02:02, 13.62s/it]
# Epoch 1... NLLLoss(Train/Test): 0.889/0.880 Accuracy(Train/Test): 0.733/0.732
#  20%|██        | 2/10 [00:27<01:49, 13.70s/it]
# Epoch 2... NLLLoss(Train/Test): 0.917/1.035 Accuracy(Train/Test): 0.714/0.707
#  30%|███       | 3/10 [00:41<01:37, 13.91s/it]
# Epoch 3... NLLLoss(Train/Test): 0.902/0.849 Accuracy(Train/Test): 0.716/0.719
#  40%|████      | 4/10 [00:55<01:23, 13.92s/it]
# Epoch 4... NLLLoss(Train/Test): 0.823/0.885 Accuracy(Train/Test): 0.746/0.745
#  50%|█████     | 5/10 [01:09<01:09, 13.89s/it]
# Epoch 5... NLLLoss(Train/Test): 0.866/0.787 Accuracy(Train/Test): 0.736/0.739
#  60%|██████    | 6/10 [01:23<00:55, 13.96s/it]
# Epoch 6... NLLLoss(Train/Test): 0.931/0.982 Accuracy(Train/Test): 0.704/0.700
#  70%|███████   | 7/10 [01:37<00:41, 13.98s/it]
# Epoch 7... NLLLoss(Train/Test): 0.887/0.774 Accuracy(Train/Test): 0.718/0.721
#  80%|████████  | 8/10 [01:51<00:27, 13.93s/it]
# Epoch 8... NLLLoss(Train/Test): 0.845/0.732 Accuracy(Train/Test): 0.743/0.746
#  90%|█████████ | 9/10 [02:05<00:13, 13.91s/it]
# Epoch 9... NLLLoss(Train/Test): 0.918/0.834 Accuracy(Train/Test): 0.707/0.712
# 100%|██████████| 10/10 [02:19<00:00, 13.93s/it]
# CPU times: user 2min 18s, sys: 3.26 s, total: 2min 21s
# Wall time: 2min 19s

# %%
my_network6=torch.nn.Sequential(*layers)
# %time train(my_network6,MyRMSProp,epochs=10, learning_rate=0.05)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 0... NLLLoss(Train/Test): 1.602/1.978 Accuracy(Train/Test): 0.687/0.673
#  10%|█         | 1/10 [00:13<02:00, 13.44s/it]
# Epoch 1... NLLLoss(Train/Test): 1.339/0.986 Accuracy(Train/Test): 0.735/0.743
#  20%|██        | 2/10 [00:26<01:47, 13.41s/it]
# Epoch 2... NLLLoss(Train/Test): 1.248/1.715 Accuracy(Train/Test): 0.756/0.751
#  30%|███       | 3/10 [00:40<01:35, 13.67s/it]
# Epoch 3... NLLLoss(Train/Test): 1.210/1.118 Accuracy(Train/Test): 0.764/0.760
#  40%|████      | 4/10 [00:54<01:22, 13.69s/it]
# Epoch 4... NLLLoss(Train/Test): 1.142/1.234 Accuracy(Train/Test): 0.776/0.769
#  50%|█████     | 5/10 [01:07<01:07, 13.58s/it]
# Epoch 5... NLLLoss(Train/Test): 1.137/1.921 Accuracy(Train/Test): 0.778/0.752
#  60%|██████    | 6/10 [01:21<00:54, 13.58s/it]
# Epoch 6... NLLLoss(Train/Test): 1.094/1.013 Accuracy(Train/Test): 0.783/0.780
#  70%|███████   | 7/10 [01:35<00:40, 13.61s/it]
# Epoch 7... NLLLoss(Train/Test): 1.051/1.177 Accuracy(Train/Test): 0.793/0.779
#  80%|████████  | 8/10 [01:49<00:27, 13.77s/it]
# Epoch 8... NLLLoss(Train/Test): 1.024/0.907 Accuracy(Train/Test): 0.795/0.798
#  90%|█████████ | 9/10 [02:02<00:13, 13.63s/it]
# Epoch 9... NLLLoss(Train/Test): 0.992/0.746 Accuracy(Train/Test): 0.805/0.810
# 100%|██████████| 10/10 [02:15<00:00, 13.58s/it]
# CPU times: user 2min 13s, sys: 2.87 s, total: 2min 16s
# Wall time: 2min 15s

# %%
my_network7=torch.nn.Sequential(*layers)
# %time train(my_network7,MyAdadelta,epochs=10, learning_rate=0.05)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 0... NLLLoss(Train/Test): 0.457/0.453 Accuracy(Train/Test): 0.877/0.877
#  10%|█         | 1/10 [00:15<02:16, 15.16s/it]
# Epoch 1... NLLLoss(Train/Test): 0.450/0.451 Accuracy(Train/Test): 0.877/0.877
#  20%|██        | 2/10 [00:31<02:08, 16.04s/it]
# Epoch 2... NLLLoss(Train/Test): 0.444/0.441 Accuracy(Train/Test): 0.877/0.877
#  30%|███       | 3/10 [00:52<02:05, 17.97s/it]
# Epoch 3... NLLLoss(Train/Test): 0.439/0.444 Accuracy(Train/Test): 0.879/0.878
#  40%|████      | 4/10 [01:11<01:50, 18.40s/it]
# Epoch 4... NLLLoss(Train/Test): 0.434/0.443 Accuracy(Train/Test): 0.880/0.879
#  50%|█████     | 5/10 [01:30<01:33, 18.75s/it]
# Epoch 5... NLLLoss(Train/Test): 0.430/0.432 Accuracy(Train/Test): 0.879/0.879
#  60%|██████    | 6/10 [01:50<01:16, 19.07s/it]
# Epoch 6... NLLLoss(Train/Test): 0.426/0.432 Accuracy(Train/Test): 0.880/0.879
#  70%|███████   | 7/10 [02:07<00:55, 18.42s/it]
# Epoch 7... NLLLoss(Train/Test): 0.423/0.428 Accuracy(Train/Test): 0.881/0.880
#  80%|████████  | 8/10 [02:21<00:34, 17.04s/it]
# Epoch 8... NLLLoss(Train/Test): 0.420/0.424 Accuracy(Train/Test): 0.880/0.880
#  90%|█████████ | 9/10 [02:35<00:16, 16.17s/it]
# Epoch 9... NLLLoss(Train/Test): 0.418/0.421 Accuracy(Train/Test): 0.881/0.881
# 100%|██████████| 10/10 [02:49<00:00, 17.00s/it]
# CPU times: user 2min 34s, sys: 4.8 s, total: 2min 39s
# Wall time: 2min 50s

# %% [markdown]
# Видим, что SGD очень стабильно обучается до хорошего уровня и почти не переобучается, Momentum за 4 эпохи обучается до 0.08 и потом переобучается, Nesterov вообще сразу переобучился, Adagrad хорошо себя ведет, Adam и RmsProp как-то странно обучаются, Adadelta обучается стабильно, но очень-очень медленно, ей нужно 200 эпох, а не 10

# %% [markdown]
# #### Feedback (опционально)

# %% [markdown]
# Здесь вы можете оставить список опечаток из лекции или семинара:

# %% [markdown]
# Здесь вы можете оставить комментарии по лекции или семинару:
