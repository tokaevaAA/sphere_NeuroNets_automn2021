# %% [markdown]
# ## Семинар 3 "Определение ключевых точек лица"

# %% [markdown]
# ## Задание

# %% [markdown]
# Используя датасет из архива решите задачу регрессии для поиска 68-ми ключевых точек лица.
#
# Для обучения и валидации используйте изображения и разметку из папок train и test соответственно.
#
# Для **зачета** дз нужно сделать одно из двух:
#
# 1. Исследовать 6 разных архитектур и написать подробный вывод + мысли почему одна сеть работает лучше чем другая (разные функции активации, глубины сетей, размеры и типы слоев)
# 2. Преодолеть порог MSE=8 на тесте
#
#
# Также до  22 марта 23:59 можно получить до 5 дополнительных баллов за лучшее решение. (За первое место 5 баллов, за второе — 3 балла, за третье — 1 балла.)
#
# Для решения можно пользоваться всем инструментарием, с которым мы познакомимся:  предобученные модели, сверточные сети, любые оптимизаторы, batchnorm, dropout, etc.

# %%
# %matplotlib inline
import os
import torch
import sys
import pandas as pd
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
from torch import nn
from torch.nn import MSELoss, Sequential, Linear, Sigmoid, Tanh, L1Loss, Module, Parameter
from torch.autograd import Variable
# Ignore warnings
import warnings


try:
    from tensorboardX import SummaryWriter
except ImportError:
    raise RuntimeError("No tensorboardX package is found. Please install with the command: \npip install tensorboardX")

from ignite.engine import Events, create_supervised_trainer, create_supervised_evaluator
from ignite.metrics import Accuracy, Loss

#pip install pytorch-ignite
#from ignite.engine import Engine, _prepare_batch

# %% [markdown]
# Есть картинки 96*96, и для каждой картинки в .csv файле есть 68 точек

# %%
warnings.filterwarnings("ignore")

landmarks_frame = pd.read_csv('dataset/train/face_landmarks.csv')

n = 100
img_name = landmarks_frame.ix[n, 0]
landmarks = landmarks_frame.ix[n, 1:].as_matrix().astype('float')
landmarks = landmarks.reshape(-1, 2)

print('Image name: {}'.format(img_name))
print('Landmarks shape: {}'.format(landmarks.shape))
print('First 4 Landmarks: {}'.format(landmarks[:4]))

def show_landmarks(image, landmarks):
    """Show image with landmarks"""
    plt.imshow(image, cmap='gray')
    plt.scatter(landmarks[:, 0], landmarks[:, 1], s=100, marker='.', c='red', cmap='rgb')
    plt.pause(0.001)  

plt.figure()
show_landmarks(io.imread(os.path.join('dataset/train/', img_name)),landmarks)
plt.show()
# Out:
# Image name: 109.jpeg
# Landmarks shape: (68, 2)
# First 4 Landmarks: [[ 7. 41.]
#  [ 8. 51.]
#  [10. 60.]
#  [13. 70.]]

# %%
#shows all images from a batch with dots 
def show_landmarks_batch(sample_batch, y_pred=None):
    """Show image with landmarks for a batch of samples."""
    images_batch, landmarks_batch = sample_batch
    batch_size = len(images_batch)
    im_size = images_batch.size(2)

    grid = utils.make_grid(images_batch)
    print(images_batch.numpy().shape)
    plt.imshow(grid.numpy().transpose(1,0,2).reshape(im_size, -1), cmap="gray")

    for i in range(batch_size):
        plt.scatter(landmarks_batch[i, :, 0].numpy() + i * im_size,
                    landmarks_batch[i, :, 1].numpy(),
                    s=10, marker='.', c='r', label='Real')

    if type(y_pred) != type(None):
        for i in range(batch_size):
            plt.scatter(y_pred[i, :, 0] + i * im_size,
                        y_pred[i, :, 1],
                        s=10, marker='.', c='b',  label='Prediction')
        plt.title('Batch from dataloader')
    plt.legend()

# %%
#dataset doesn't store images themselves, but only the rule how to get them
class FaceLandmarksDataset(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, csv_file, root_dir, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.landmarks_frame = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.landmarks_frame)

    def __getitem__(self, idx):
        img_name = os.path.join(self.root_dir, self.landmarks_frame.iloc[idx, 0])
        image = io.imread(img_name)
        landmarks = self.landmarks_frame.iloc[idx, 1:].as_matrix().astype('float')
        landmarks = landmarks.reshape(-1, 2)
        sample = image, landmarks

        if self.transform:
            sample = self.transform(sample)

        return sample

# %%
class RandomCrop(object):
    """Crop randomly the image in a sample.

    Args:
        output_size (tuple or int): Desired output size. If int, square crop is made.
    """

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        if isinstance(output_size, int):
            self.output_size = (output_size, output_size)
        else:
            assert len(output_size) == 2
            self.output_size = output_size

    def __call__(self, sample):
        image, landmarks = sample

        h, w = image.shape[:2]
        new_h, new_w = self.output_size

        top = np.random.randint(0, h - new_h)
        left = np.random.randint(0, w - new_w)

        image = image[top: top + new_h, left: left + new_w]
        landmarks = landmarks - [left, top]

        return image, landmarks




class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""

    def __call__(self, sample):
        image, landmarks = sample
        return torch.from_numpy(image).type(torch.float), torch.from_numpy(landmarks).type(torch.float)

# %%
train_dataset = FaceLandmarksDataset(csv_file='dataset/train/face_landmarks.csv',
                                     root_dir='dataset/train',
                                     transform=ToTensor())

test_dataset = FaceLandmarksDataset(csv_file='dataset/test/face_landmarks.csv',
                                     root_dir='dataset/test',
                                     transform=ToTensor())

def get_data_loaders(train_batch_size=64, val_batch_size=64):
    train_loader = DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=val_batch_size, shuffle=False)
    return train_loader, test_loader

# %%
def train(network, epochs, learning_rate):
    loss = MSELoss()
    optimizer = torch.optim.Adam(network.parameters(), lr=learning_rate)
    train_loss_epochs = []
    test_loss_epochs = []
    train_accuracy_epochs = []
    test_accuracy_epochs = []
    try:
        for epoch in range(epochs):
            losses = []
            accuracies = []
            for X, y in train_loader:
                network.zero_grad()
                prediction = network(X)
                #print(y.shape) #64*68*2
                #print(prediction.shape)#64*68*2
                loss_batch = loss(prediction, y)
                losses.append(loss_batch.item())
                loss_batch.backward()
                optimizer.step()
                #accuracies.append((np.argmax(prediction.data.numpy(), 1)==y.data.numpy()).mean())
            train_loss_epochs.append(np.mean(losses))
            #train_accuracy_epochs.append(np.mean(accuracies))
            
            losses = []
            accuracies = []    
            for X, y in test_loader:
                prediction = network(X)
                loss_batch = loss(prediction, y)
                losses.append(loss_batch.item())
                #accuracies.append((np.argmax(prediction.data.numpy(), 1)==y.data.numpy()).mean())
            test_loss_epochs.append(np.mean(losses))
            #test_accuracy_epochs.append(np.mean(accuracies))
            #clear_output(True)
            print('\rEpoch {0}... (Train/Test) MSE: {1:.3f}/{2:.3f}'.format(
                        epoch, train_loss_epochs[-1], test_loss_epochs[-1]))
            
            
            plt.figure(figsize=(12, 5))
            plt.subplot(1, 1, 1)
            plt.plot(train_loss_epochs, label='Train')
            plt.plot(test_loss_epochs, label='Test')
            plt.xlabel('Epochs', fontsize=16)
            plt.ylabel('Loss', fontsize=16)
            plt.legend(loc=0, fontsize=16)
            plt.grid()
            plt.show()
    except KeyboardInterrupt:
        pass

# %%
#initial Net
class Net0(Module):
    def __init__(self, activation=Sigmoid(), latent_size=200):
        super().__init__()
        self.fc1 =Linear(96 * 96, 200)
        self.fc2 = Linear(200, 68 * 2)
        self.activation = activation
    def forward(self, x):
        return self.fc2(self.activation(self.fc1(x.view(x.shape[0], -1)))).view(x.shape[0], 68, 2)

network0 = Net0()
train_loader, test_loader = get_data_loaders()
# %time train(network0, 10,0.01)
# Out:
# Epoch 0... (Train/Test) MSE: 834.527/41.787
# Epoch 1... (Train/Test) MSE: 21.356/18.538
# Epoch 2... (Train/Test) MSE: 17.533/18.541
# Epoch 3... (Train/Test) MSE: 17.495/18.571
# Epoch 4... (Train/Test) MSE: 17.536/18.570
# Epoch 5... (Train/Test) MSE: 17.960/18.565
# Epoch 6... (Train/Test) MSE: 17.531/18.546
# Epoch 7... (Train/Test) MSE: 17.512/18.542
# Epoch 8... (Train/Test) MSE: 17.510/18.559
# Epoch 9... (Train/Test) MSE: 17.509/18.619
# CPU times: user 2min 8s, sys: 18.3 s, total: 2min 26s
# Wall time: 2min 16s

# %%
#MSE=18

# %%
#let's change Sigmoid to ReLU
image_size = 96
channels = 1
class Net1(nn.Module):
    def __init__(self):
        super(Net1, self).__init__()
        #self.conv_layers = nn.Sequential(nn.Conv2d(channels, 3, 3, padding=1), nn.ReLU(), nn.MaxPool2d(2))
        self.linear_layers = nn.Sequential(
            nn.Linear(image_size*image_size, 200), 
            nn.ReLU(), 
            nn.Linear(200, 68*2))
    
    def forward(self, x):
#         x = self.conv_layers(x)
        x = x.view(x.size(0), -1)
        x = self.linear_layers(x)
        x=x.reshape(-1,68,2)
        return x
    
network1 = Net1()
train_loader, test_loader = get_data_loaders()
# %time train(network1, 10,0.01)
# Out:
# Epoch 0... (Train/Test) MSE: 970063.815/3269.938
# Epoch 1... (Train/Test) MSE: 3280.848/3260.655
# Epoch 2... (Train/Test) MSE: 3268.512/3248.418
# Epoch 3... (Train/Test) MSE: 3255.883/3233.717
# Epoch 4... (Train/Test) MSE: 3240.599/3216.809
# Epoch 5... (Train/Test) MSE: 3221.841/3197.864
# Epoch 6... (Train/Test) MSE: 3202.311/3177.010
# Epoch 7... (Train/Test) MSE: 3179.737/3154.343
# Epoch 8... (Train/Test) MSE: 3156.565/3129.937
# Epoch 9... (Train/Test) MSE: 3131.284/3103.866
# CPU times: user 2min 15s, sys: 20.1 s, total: 2min 35s
# Wall time: 2min 31s

# %%
#Видим, что у ReLU вообще другой MSE, сильно больше сигмоиды

# %%
#let's add BatchNorm = ReLU+BatchNorm
image_size = 96
channels = 1
class Net2(nn.Module):
    def __init__(self):
        super(Net2, self).__init__()
        #self.conv_layers = nn.Sequential(nn.Conv2d(channels, 3, 3, padding=1), nn.ReLU(), nn.MaxPool2d(2))
        self.linear_layers = nn.Sequential(
            nn.Linear(image_size*image_size, 200), 
            nn.BatchNorm1d(200), 
            nn.ReLU(), 
            nn.Linear(200, 68*2))
    
    def forward(self, x):
#         x = self.conv_layers(x)
        x = x.view(x.size(0), -1)
        x = self.linear_layers(x)
        x=x.reshape(-1,68,2)
        return x
    
network2 = Net2()
train_loader, test_loader = get_data_loaders()
# %time train(network2, 40,0.08)
# Out:
# Epoch 0... (Train/Test) MSE: 200.977/15.714
# Epoch 1... (Train/Test) MSE: 12.952/12.918
# Epoch 2... (Train/Test) MSE: 11.062/11.904
# Epoch 3... (Train/Test) MSE: 10.389/12.040
# Epoch 4... (Train/Test) MSE: 9.761/12.961
# Epoch 5... (Train/Test) MSE: 9.544/10.769
# Epoch 6... (Train/Test) MSE: 8.849/11.394
# Epoch 7... (Train/Test) MSE: 8.852/14.423
# Epoch 8... (Train/Test) MSE: 8.787/12.183
# Epoch 9... (Train/Test) MSE: 8.056/10.688
# Epoch 10... (Train/Test) MSE: 8.164/9.836
# Epoch 11... (Train/Test) MSE: 7.834/9.573
# Epoch 12... (Train/Test) MSE: 7.525/11.147
# Epoch 13... (Train/Test) MSE: 7.589/11.645
# Epoch 14... (Train/Test) MSE: 7.421/10.657
# Epoch 15... (Train/Test) MSE: 7.149/11.171
# Epoch 16... (Train/Test) MSE: 7.434/9.503
# Epoch 17... (Train/Test) MSE: 7.083/9.374
# Epoch 18... (Train/Test) MSE: 7.095/10.215
# Epoch 19... (Train/Test) MSE: 7.007/11.207
# Epoch 20... (Train/Test) MSE: 6.873/10.485
# Epoch 21... (Train/Test) MSE: 6.970/10.596
# ...

# %%
#Видим, что BatchNorm - очень сильно улучшает сеть!

# %%
#let's add Dropout = ReLU+BatchNorm+Dropout
image_size = 96
channels = 1
class Net3(nn.Module):
    def __init__(self):
        super(Net3, self).__init__()
        #self.conv_layers = nn.Sequential(nn.Conv2d(channels, 3, 3, padding=1), nn.ReLU(), nn.MaxPool2d(2))
        self.linear_layers = nn.Sequential(
            nn.Linear(image_size*image_size, 200), 
            nn.BatchNorm1d(200), 
            nn.ReLU(),
            nn.Dropout(),
            nn.Linear(200, 68*2)
        )
    
    def forward(self, x):
#         x = self.conv_layers(x)
        x = x.view(x.size(0), -1)
        x = self.linear_layers(x)
        x=x.reshape(-1,68,2)
        return x
    
network3 = Net3()
train_loader, test_loader = get_data_loaders()
# %time train(network3, 10,0.05)
# Out:
# Epoch 0... (Train/Test) MSE: 280.485/43.452
# Epoch 1... (Train/Test) MSE: 35.611/37.495
# Epoch 2... (Train/Test) MSE: 34.138/35.367
# Epoch 3... (Train/Test) MSE: 32.904/36.126
# Epoch 4... (Train/Test) MSE: 31.953/32.288
# Epoch 5... (Train/Test) MSE: 31.069/32.218
# Epoch 6... (Train/Test) MSE: 32.010/31.807
# Epoch 7... (Train/Test) MSE: 30.932/34.433
# Epoch 8... (Train/Test) MSE: 32.984/35.272
# Epoch 9... (Train/Test) MSE: 31.747/31.237
# CPU times: user 5min 7s, sys: 57.4 s, total: 6min 5s
# Wall time: 13min 37s

# %%
#Видим, что Dropout почти ничего не дает, и еще долго работает

# %%
#let's add one more BatchNorm and delete Dropout = ReLU+2BatchNorm
image_size = 96
channels = 1
class Net4(nn.Module):
    def __init__(self):
        super(Net4, self).__init__()
        #self.conv_layers = nn.Sequential(nn.Conv2d(channels, 3, 3, padding=1), nn.ReLU(), nn.MaxPool2d(2))
        self.linear_layers = nn.Sequential(
            nn.Linear(image_size*image_size, 200), 
            nn.BatchNorm1d(200), 
            nn.ReLU(),
            nn.Linear(200, 150), 
            nn.BatchNorm1d(150), 
            nn.ReLU(),
            nn.Linear(150, 68*2)
        )
    
    def forward(self, x):
#         x = self.conv_layers(x)
        x = x.view(x.size(0), -1)
        x = self.linear_layers(x)
        x=x.reshape(-1,68,2)
        return x
    
network4 = Net4()
train_loader, test_loader = get_data_loaders()
# %time train(network4, 20,0.05)
# %time train(network4, 10,0.01)
# %time train(network4, 10,0.005)
# Out:
# Epoch 0... (Train/Test) MSE: 231.771/22.460
# Epoch 1... (Train/Test) MSE: 21.617/29.373
# Epoch 2... (Train/Test) MSE: 20.614/18.461
# Epoch 3... (Train/Test) MSE: 16.106/16.168
# Epoch 4... (Train/Test) MSE: 13.385/14.242
# Epoch 5... (Train/Test) MSE: 11.177/13.410
# Epoch 6... (Train/Test) MSE: 10.466/12.086
# Epoch 7... (Train/Test) MSE: 9.808/13.138
# Epoch 8... (Train/Test) MSE: 9.149/11.628
# Epoch 9... (Train/Test) MSE: 8.813/10.569
# Epoch 10... (Train/Test) MSE: 8.095/11.485
# Epoch 11... (Train/Test) MSE: 7.570/10.024
# Epoch 12... (Train/Test) MSE: 6.942/9.402
# Epoch 13... (Train/Test) MSE: 6.742/10.129
# Epoch 14... (Train/Test) MSE: 6.719/10.235
# Epoch 15... (Train/Test) MSE: 6.608/9.140
# Epoch 16... (Train/Test) MSE: 6.352/9.726
# Epoch 17... (Train/Test) MSE: 6.019/8.918
# Epoch 18... (Train/Test) MSE: 6.008/9.026
# Epoch 19... (Train/Test) MSE: 6.258/10.071
# CPU times: user 4min 27s, sys: 41.3 s, total: 5min 8s
# Wall time: 4min 45s
# ...

# %% [markdown]
# ### УРА!!! Достигли MSE<8!

# %%
#let's add Conv2d = ReLU+2BatchNorm+Dropout+Conv2d
image_size = 96
channels = 1
class Net5(nn.Module):
    def __init__(self):
        super(Net5, self).__init__()
        self.conv_layers = nn.Sequential(
            nn.Conv2d(1, 1, 3, padding=1), 
            nn.ReLU(), 
            nn.MaxPool2d(2)
        )
        self.linear_layers = nn.Sequential(
            nn.Linear(image_size//2*image_size//2, 200), 
            nn.BatchNorm1d(200), 
            nn.ReLU(),
            nn.Linear(200, 150), 
            nn.BatchNorm1d(150), 
            nn.ReLU(),
            nn.Linear(150, 68*2)
        )
    
    def forward(self, x):
        x=x.reshape(-1,1,96,96)
        x = self.conv_layers(x)
        x = x.view(x.size(0), -1)
        x = self.linear_layers(x)
        x=x.reshape(-1,68,2)
        return x
    
network5 = Net5()
train_loader, test_loader = get_data_loaders()
# %time train(network5, 20,0.05)
# %time train(network5, 10,0.01)
# %time train(network5, 10,0.005)
# Out:
# Epoch 0... (Train/Test) MSE: 239.848/28.457
# Epoch 1... (Train/Test) MSE: 23.313/26.478
# Epoch 2... (Train/Test) MSE: 21.072/23.491
# Epoch 3... (Train/Test) MSE: 21.628/21.985
# Epoch 4... (Train/Test) MSE: 19.918/21.208
# Epoch 5... (Train/Test) MSE: 19.326/19.894
# Epoch 6... (Train/Test) MSE: 18.132/20.293
# Epoch 7... (Train/Test) MSE: 17.928/20.189
# Epoch 8... (Train/Test) MSE: 17.552/19.627
# Epoch 9... (Train/Test) MSE: 17.709/19.232
# Epoch 10... (Train/Test) MSE: 15.853/16.286
# Epoch 11... (Train/Test) MSE: 11.917/12.943
# Epoch 12... (Train/Test) MSE: 9.990/11.490
# Epoch 13... (Train/Test) MSE: 8.602/10.539
# Epoch 14... (Train/Test) MSE: 7.623/10.394
# Epoch 15... (Train/Test) MSE: 7.264/11.322
# Epoch 16... (Train/Test) MSE: 6.755/9.960
# Epoch 17... (Train/Test) MSE: 6.023/11.182
# Epoch 18... (Train/Test) MSE: 5.957/10.980
# Epoch 19... (Train/Test) MSE: 5.250/9.467
# CPU times: user 5min 40s, sys: 1min 24s, total: 7min 4s
# Wall time: 6min 55s
# ...

# %%
#Видим, что немножко похуже, чем Net4

# %%
#let's add one more Conv2d = ReLU+2BatchNorm+Dropout+Conv2d+Conv2d
image_size = 96
channels = 1
class Net6(nn.Module):
    def __init__(self):
        super(Net6, self).__init__()
        self.conv_layers = nn.Sequential(
            nn.Conv2d(1, 8, 3, padding=1), 
            nn.ReLU(), 
            nn.MaxPool2d(2),
            nn.Conv2d(8, 16, 3, padding=1), 
            nn.ReLU(), 
            nn.MaxPool2d(2),
        )
        self.linear_layers = nn.Sequential(
            nn.Linear(16*image_size//(2*2)*image_size//(2*2), 400), 
            nn.BatchNorm1d(400), 
            nn.ReLU(),
            nn.Linear(400, 200), 
            nn.BatchNorm1d(200), 
            nn.ReLU(),
            nn.Linear(200, 68*2)
        )
    
    def forward(self, x):
        x=x.reshape(-1,1,96,96)
        x = self.conv_layers(x)
        x = x.view(x.size(0), -1)
        x = self.linear_layers(x)
        x=x.reshape(-1,68,2)
        return x
    
network6 = Net6()
train_loader, test_loader = get_data_loaders()
# %time train(network6, 20,0.05)
# %time train(network6, 10,0.01)
# %time train(network6, 10,0.005)
# Out:
# Epoch 0... (Train/Test) MSE: 208.627/25.100
# Epoch 1... (Train/Test) MSE: 22.733/21.342
# Epoch 2... (Train/Test) MSE: 20.103/20.279
# Epoch 3... (Train/Test) MSE: 17.794/18.004
# Epoch 4... (Train/Test) MSE: 15.251/16.201
# Epoch 5... (Train/Test) MSE: 13.254/14.529
# Epoch 6... (Train/Test) MSE: 12.129/12.894
# Epoch 7... (Train/Test) MSE: 10.984/12.712
# Epoch 8... (Train/Test) MSE: 10.033/12.251
# Epoch 9... (Train/Test) MSE: 9.920/11.657
# Epoch 10... (Train/Test) MSE: 8.875/10.311
# Epoch 11... (Train/Test) MSE: 7.723/9.417
# Epoch 12... (Train/Test) MSE: 6.816/8.630
# Epoch 13... (Train/Test) MSE: 6.385/7.678
# Epoch 14... (Train/Test) MSE: 5.741/7.421
# Epoch 15... (Train/Test) MSE: 5.339/7.120
# Epoch 16... (Train/Test) MSE: 4.792/7.024
# Epoch 17... (Train/Test) MSE: 4.721/7.815
# Epoch 18... (Train/Test) MSE: 4.184/6.664
# Epoch 19... (Train/Test) MSE: 4.305/7.573
# CPU times: user 15min 26s, sys: 3min 48s, total: 19min 15s
# Wall time: 20min 33s
# ...

# %% [markdown]
# # А Net6 вообще обучилась до MSE=5.6!!!!

# %%
Посмотрим на предсказание:

# %%
_, test_dataloader = get_data_loaders(val_batch_size=2)

images_batch = next(iter(test_dataloader))
x, y = images_batch
y_pred = network6(x)
y_pred = y_pred.data.numpy()
show_landmarks_batch(images_batch, y_pred)
# Out:
# (2, 96, 96)

# %% [markdown]
# # Выводы:

# %% [markdown]
# 1) BatchNorm-очень мощная и полезная штука, надо использовать

# %% [markdown]
# 2) Dropout не стоит применять, лучше изменить архитектуру сети, добавить сверточные слои или BatchNorm

# %% [markdown]
# 3) Net4 обучилась до MSE=7.7 (это просто два BatchNorm-a)

# %% [markdown]
# 4) Net6 обучилась до MSE=5.6 (это два сверточных слоя и два BatchNorm)

# %% [markdown]
# 5) Лучший результат показала Net6, это MSE=5.6
